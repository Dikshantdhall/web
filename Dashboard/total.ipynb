# %%
import pandas as pd

# %%
df_first = pd.read_csv("total.csv")

# %%
df_first
# Out:
#       DATE  COUNT  INACTIVE  ACTIVE    A   B   C  OWNER INITIATED  \
# 0   18-Jan    718       131     587  660  55   3               17
# 1   18-Feb    635       106     529  597  36   2               18
# 2   18-Mar    597        88     509  564  30   3               12
# 3   18-Apr    774       134     640  725  44   5               19
# 4   18-May    843       137     706  793  45   5               22
# 5   18-Jun    764       108     656  725  37   2                8
# 6   19-Aug    721        13     708  666  51   4               19
# 7   19-Nov    628         1     627  601  25   2               18
# 8   18-Jul    815        96     719  767  45   3               13
# 9   18-Sep    842        86     756  769  60   9               18
# 10  18-Aug    846       103     743  794  49   3               18
# 11  18-Oct    823        78     745  768  50   5               29
# 12  18-Nov    529        47     482  505  22   2               11
# ...

# %%
df_first.to_json("total.json", orient ="records")
