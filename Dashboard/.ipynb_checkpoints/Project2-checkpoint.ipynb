# %%
# import csv
# import json

# csvfile = open('smdata.csv', 'r',encoding='utf-8')
# jsonfile = open('file.json', 'w',encoding='utf-8')

# fieldnames = ("ACTIVITY DATE", "FACILITY NAME","PE DESCRIPTION","FACILITY ADDRESS","FACILITY CITY","FACILITY STATE","FACILITY ZIP","SERVICE DESCRIPTION","SCORE","GRADE","Longitude","Lattitude")
# reader = csv.DictReader( csvfile)
# for row in reader:
#     json.dump(row, jsonfile)
#     jsonfile.write('\n')

# %%
import pandas as pd

# %%
df_csv = pd.read_csv("smdata.csv")

# %%
df_csv.head()
# Out:
#   ACTIVITY DATE     FACILITY NAME                          PE DESCRIPTION  \
# 0     6/28/2018            NA TIV      RESTAURANT (31-60) SEATS HIGH RISK
# 1      6/7/2018        THE GALLEY     RESTAURANT (61-150) SEATS HIGH RISK
# 2     2/14/2018       IZZY'S DELI     RESTAURANT (61-150) SEATS HIGH RISK
# 3      8/1/2017     SUBWAY #61747   RESTAURANT (0-30) SEATS MODERATE RISK
# 4     6/16/2017  18TH STREET CAFE  RESTAURANT (31-60) SEATS MODERATE RISK
#
#               FACILITY ADDRESS FACILITY CITY FACILITY STATE FACILITY ZIP  \
# 0  620 SANTA MONICA BLVD STE A  SANTA MONICA             CA        90401
# 1                 2442 MAIN ST  SANTA MONICA             CA        90405
# 2           1433 WILSHIRE BLVD  SANTA MONICA             CA        90403
# 3    2461 SANTA MONICA BLVD #B  SANTA MONICA             CA   90404-2065
# 4                1725 BROADWAY  SANTA MONICA             CA        90404
#
#   SERVICE DESCRIPTION  SCORE GRADE   Longitude  Lattitude
# ...

# %%
df_csv.to_json (r'DataFrame.json', orient='records')
