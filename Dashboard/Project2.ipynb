# %%
import pandas as pd

# %%
df_csv = pd.read_csv("LA.csv")

# %%
df_csv.head()
# Out:
#   ACTIVITY DATE   OWNER ID             OWNER NAME FACILITY ID  \
# 0      6/7/2017  OW0007353         CHEN, CHAO SHU   FA0070050
# 1     6/20/2017  OW0242297           YOUNG HWA KO   FA0247762
# 2     6/21/2017  OW0124280  SERAPIA LOPEZ QUEZADA   FA0159262
# 3     6/23/2017  OW0240340         SEULKEE E PARK   FA0245257
# 4      7/5/2017  OW0019032           KIM ANN CHOI   FA0072034
#
#      FACILITY NAME  RECORD ID     PROGRAM NAME PROGRAM STATUS  \
# 0         SAN HING  PR0004325         SAN HING       INACTIVE
# 1  FATBURGER #1076  PR0196395  FATBURGER #1076         ACTIVE
# 2      DON QUIXOTE  PR0147326      DON QUIXOTE       INACTIVE
# 3         HULAFISH  PR0193641         HULAFISH       INACTIVE
# 4    TERIYAKI ME !  PR0012374    TERIYAKI ME !         ACTIVE
#
#    PROGRAM ELEMENT (PE)                           PE DESCRIPTION  ...  \
# 0                  1632        RESTAURANT (0-30) SEATS HIGH RISK  ...
# 1                  1631    RESTAURANT (0-30) SEATS MODERATE RISK  ...
# ...

# %%
df =  df_csv[df_csv['FACILITY CITY'].isin(["LOS ANGELES"])]

# %%
LosAngeles_df = df[df['FACILITY ZIP'].isin(['90034', '90023', '90011', '90064', '90029', '90045', '90015', '90014', '90024', '90046', '90022','90012', '90023', '90038', '90015', '90016', '90019', 
'90037', '90004', '90039', '90048', '90018'])]

# %%
LosAngeles_df.to_json("La.json", orient ="records")

# %%
LosAngeles_df.to_csv("LosAngeles.csv")
